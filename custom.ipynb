# %%
# !/usr/local/cuda/bin/nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Mon Jul 11 09:05:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone 'https://github.com/AlexeyAB/darknet' '/content/gdrive/MyDrive/custom/darknet'
# Out:
# fatal: destination path '/content/gdrive/MyDrive/custom/darknet' already exists and is not an empty directory.

# %%
# %cd /content/gdrive/MyDrive/custom/darknet
# Out:
# /content/gdrive/MyDrive/custom/darknet

# %%
# !make clean
# Out:
# rm -rf ./obj/image_opencv.o ./obj/http_stream.o ./obj/gemm.o ./obj/utils.o ./obj/dark_cuda.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/darknet.o ./obj/detection_layer.o ./obj/captcha.o ./obj/route_layer.o ./obj/writing.o ./obj/box.o ./obj/nightmare.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/coco.o ./obj/dice.o ./obj/yolo.o ./obj/detector.o ./obj/layer.o ./obj/compare.o ./obj/classifier.o ./obj/local_layer.o ./obj/swag.o ./obj/shortcut_layer.o ./obj/representation_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/rnn.o ./obj/rnn_vid.o ./obj/crnn_layer.o ./obj/demo.o ./obj/tag.o ./obj/cifar.o ./obj/go.o ./obj/batchnorm_layer.o ./obj/art.o ./obj/region_layer.o ./o
# ...

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=24/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=8/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@classes=255@classes=35@' cfg/yolov3_training.cfg
# !sed -i '689 s@classes=255@classes=35@' cfg/yolov3_training.cfg
# !sed -i '776 s@classes=255@classes=35@' cfg/yolov3_training.cfg

# %%
# !mkdir "/content/gdrive/MyDrive/custom/weights"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/custom/weights’: File exists

# %%
# !echo -e 'Chen-Shih-Chung\nK_P' > data/obj.names
# !echo -e 'classes= 1\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /content/gdrive/MyDrive/custom/weights' > data/obj.data
# !mkdir data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-07-11 02:18:42--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  71.9MB/s    in 2.2s
#
# 2022-07-11 02:18:44 (71.9 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !unzip /content/gdrive/MyDrive/custom/mydata/images.zip -d data/obj
# Out:
# Archive:  /content/gdrive/MyDrive/custom/mydata/images.zip
#   inflating: data/obj/datasets/00001.jpg
#   inflating: data/obj/datasets/00001.txt
#   inflating: data/obj/datasets/00002.jpg
#   inflating: data/obj/datasets/00002.txt
#   inflating: data/obj/datasets/00003.jpg
#   inflating: data/obj/datasets/00003.txt
#   inflating: data/obj/datasets/00004.jpg
#   inflating: data/obj/datasets/00004.txt
#   inflating: data/obj/datasets/00005.jpg
#   inflating: data/obj/datasets/00005.txt
#   inflating: data/obj/datasets/00006.jpg
#   inflating: data/obj/datasets/00006.txt
#   inflating: data/obj/datasets/00007.jpg
#   inflating: data/obj/datasets/00007.txt
#   inflating: data/obj/datasets/00008.jpg
#   inflating: data/obj/datasets/00008.txt
#   inflating: data/obj/datasets/00009.jpg
#   inflating: data/obj/datasets/00009.txt
#   inflating: data/obj/datasets/00010.jpg
#   inflating: data/obj/datasets/00010.txt
#   inflating: data/obj/datasets/00011.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/datasets/*.jpg")
print(images_list)
# Out:
# ['data/obj/datasets/00001.jpg', 'data/obj/datasets/00002.jpg', 'data/obj/datasets/00003.jpg', 'data/obj/datasets/00004.jpg', 'data/obj/datasets/00005.jpg', 'data/obj/datasets/00006.jpg', 'data/obj/datasets/00007.jpg', 'data/obj/datasets/00008.jpg', 'data/obj/datasets/00009.jpg', 'data/obj/datasets/00010.jpg', 'data/obj/datasets/00011.jpg', 'data/obj/datasets/00012.jpg', 'data/obj/datasets/00013.jpg', 'data/obj/datasets/00014.jpg', 'data/obj/datasets/00015.jpg', 'data/obj/datasets/00016.jpg', 'data/obj/datasets/00017.jpg', 'data/obj/datasets/00018.jpg', 'data/obj/datasets/00019.jpg', 'data/obj/datasets/00020.jpg', 'data/obj/datasets/00021.jpg', 'data/obj/datasets/00022.jpg', 'data/obj/datasets/00023.jpg', 'data/obj/datasets/00024.jpg', 'data/obj/datasets/00025.jpg', 'data/obj/datasets/00026.jpg', 'data/obj/datasets/00027.jpg', 'data/obj/datasets/00028.jpg', 'data/obj/datasets/00029.jpg', 'data/obj/datasets/00030.jpg', 'data/obj/datasets/00031.jpg', 'data/obj/datasets/00032.jpg', 'data
# ...

# %%
file = open("data/train.txt", "w")
file.write("\n".join(images_list))
file.close()

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 92949, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.939883), count: 3, class_loss = 0.000008, iou_loss = 0.019727, total_loss = 0.019735
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 92952, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.926295), count: 5, class_loss = 0.000054, iou_loss = 0.033563, total_loss = 0.033616
# ...

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/custom/weights/yolov3_training_final.weights data/obj/datasets/00001.jpg
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  There isn't such command: data/obj.data
